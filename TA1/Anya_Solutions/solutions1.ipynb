# %%
print("Hello world")
# Out:
# Hello world

# %%
items=["glass","cups","spoons","plates","fork"]

# %%
print(items[0])
print(items)
for item in items:
    print(item)
# Out:
# glass
# ['glass', 'cups', 'spoons', 'plates', 'fork']
# glass
# cups
# spoons
# plates
# fork

# %%
# items.reverse()
# print(items)

# %%
for item in items[::-1]:
    print(item)
# Out:
# fork
# plates
# spoons
# cups
# glass

# %%
print(item[-1])
# Out:
# fork

# %%
items.append("bottle")
print(items)
# Out:
# ['glass', 'cups', 'spoons', 'plates', 'fork', 'bottle']

# %%
neces=items.pop()
print(neces)
print(items)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_921/4082720595.py in <cell line: 0>()
# ----> 1 neces=items.pop()
#       2 print(neces)
#       3 print(items)
#
# IndexError: pop from empty list

# %%
print(items.pop())
# Out:
# fork

# %%
kitchen="fork"
print(items)
# Out:
# ['glass', 'cups', 'spoons', 'plates']

# %%
#for left end
colours=["blue","black","red","green","yellow"]
for colour in colours[::-1]:
    print(colour)
colours.append("maroon")
print(colours)
colours.pop()
shades="maroon"
print(shades)
# Out:
# yellow
# green
# red
# black
# blue
# ['blue', 'black', 'red', 'green', 'yellow', 'maroon']
# maroon

# %%
colours=[] #for storage

#
